# %% [markdown]
# # PANDAS:

# %% [markdown]
# - Series (1 dimensional):

# %%
import pandas as pd

# %%
s = pd.Series(
    [
        1,
        2,
        3,
        4,
        5,
    ],
    index=["a", "b", "c", "d", "e"],
)

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# - DataFrame (2 dimensional):

# %%
df = pd.DataFrame({"names": ["Zeeshan", "Rehan"], "age": [22, 28]})

# %%
df
# Out:
#      names  age
# 0  Zeeshan   22
# 1    Rehan   28

# %%
df = pd.read_csv("data/Form1.csv")

# %%
df
# Out:
#                Column 1                         Column 2  \
# 0   27/08/2025 16:01:53             abbash3834@gmail.com
# 1   27/08/2025 15:23:46          abdulmoeid173@gmail.com
# 2   27/08/2025 18:42:47           madeelasif22@gmail.com
# 3   27/08/2025 15:22:09        princeahmed8966@gmail.com
# 4   27/08/2025 16:54:27             jali084337@gmail.com
# 5   27/08/2025 16:01:30          amadashraf489@gmail.com
# 6   27/08/2025 16:49:41         sardarasad6113@gmail.com
# 7   27/08/2025 16:14:39        faizanzaheer484@gmail.com
# 8   27/08/2025 18:03:51         zohaibnawaz877@gmail.com
# 9   27/08/2025 14:42:41         mohibahmad1177@gmail.com
# 10  27/08/2025 15:29:14              haadishk1@gmail.com
# 11  27/08/2025 15:08:59  muhammadhamzahamza717@gmail.com
# 12  27/08/2025 18:40:34         hafizusman733k@gmail.com
# 13  27/08/2025 16:11:27             rameezmlk1@gmail.com
# 14  27/08/2025 14:42:05            ulhassanr59@gmail.com
# ...

# %%
df.head()
# Out:
#               Column 1                   Column 2       Column 3 Column 4  \
# 0  27/08/2025 16:01:53       abbash3834@gmail.com  ABBAS HAIDER    Fc 209
# 1  27/08/2025 15:23:46    abdulmoeid173@gmail.com    Abdul Moeid   FC-181
# 2  27/08/2025 18:42:47     madeelasif22@gmail.com     Adeel Asif      214
# 3  27/08/2025 15:22:09  princeahmed8966@gmail.com  Ahmed Akraam    FC-217
# 4  27/08/2025 16:54:27       jali084337@gmail.com     Ali Javed    FC-200
#
#                                      Column 5                       Column 6
# 0  Python for Data Science & Machine Learning    Software Project Management
# 1  Python for Data Science & Machine Learning    Software Project Management
# 2  Python for Data Science & Machine Learning    Software Project Management
# 3  Python for Data Science & Machine Learning    Software Project Management
# 4  Python for Data Science & Machine Learning  Software Testing & Automation

# %%
df.tail()
# Out:
#                Column 1                   Column 2                Column 3  \
# 20  27/08/2025 16:20:58   zuhaibzafar589@gmail.com           Zuhaib zafar
# 21  27/08/2025 20:29:00  fahadshahbaz166@gmail.com  Muhammad Fahad Shahbaz
# 22  27/08/2025 20:30:56   dawoodmasood12@gmail.com          Dawood masood
# 23  27/08/2025 20:31:08        farazdj84@gmail.com                   Faraz
# 24  28/08/2025 11:49:57   umerrehman9922@gmail.com             Umer Rehman
#
#    Column 4                                    Column 5  \
# 20   Fc-204  Python for Data Science & Machine Learning
# 21   FC-171  Python for Data Science & Machine Learning
# 22  Fc-168   Python for Data Science & Machine Learning
# 23   Fc-169  Python for Data Science & Machine Learning
# 24    FC170  Python for Data Science & Machine Learning
#
#                        Column 6
# 20  Software Project Management
# 21  Software Project Management
# 22  Software Project Management
# 23  Software Project Management
# ...

# %%
df.describe()
# Out:
#                    Column 1              Column 2       Column 3 Column 4  \
# count                    25                    25             25       25
# unique                   25                    25             25       25
# top     27/08/2025 16:01:53  abbash3834@gmail.com  ABBAS HAIDER    Fc 209
# freq                      1                     1              1        1
#
#                                           Column 5  \
# count                                           25
# unique                                           2
# top     Python for Data Science & Machine Learning
# freq                                            23
#
#                            Column 6
# count                            25
# unique                            2
# top     Software Project Management
# freq                             22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column 1  25 non-null     object
#  1   Column 2  25 non-null     object
#  2   Column 3  25 non-null     object
#  3   Column 4  25 non-null     object
#  4   Column 5  25 non-null     object
#  5   Column 6  25 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
df["Column 3"] #! case sensitive!! "column 3" won't work.
# Out:
# 0              ABBAS HAIDER
# 1                Abdul Moeid
# 2                 Adeel Asif
# 3              Ahmed Akraam
# 4                 Ali Javed
# 5                Amad Ashraf
# 6               Asad Sardar
# 7           M Faizan Zaheer
# 8             M zohaib nawaz
# 9                Mohib Ahmad
# 10           Muhammad Haddi
# 11            Muhammad Hamza
# 12            Muhammad Usman
# 13              Rameez Ahmad
# 14         Rameez Ul Hassan
# 15                Saif Ullah
# 16           Saqlain Mahmood
# 17             Shoaib Azhar
# 18             Zeeshan Munir
# 19             Zohaib tariq
# 20             Zuhaib zafar
# 21    Muhammad Fahad Shahbaz
# 22            Dawood masood
# 23                     Faraz
# 24               Umer Rehman
# Name: Column 3, dtype: object

# %%
df[["Column 4","Column 3"]]
# Out:
#    Column 4                Column 3
# 0    Fc 209           ABBAS HAIDER
# 1    FC-181             Abdul Moeid
# 2       214              Adeel Asif
# 3    FC-217           Ahmed Akraam
# 4    FC-200              Ali Javed
# 5    Fc-147             Amad Ashraf
# 6   FC -211            Asad Sardar
# 7    FC-218        M Faizan Zaheer
# 8    fc 215          M zohaib nawaz
# 9    Fc 180             Mohib Ahmad
# 10   FC-173         Muhammad Haddi
# 11   FC-213          Muhammad Hamza
# 12   FC-175          Muhammad Usman
# 13   Fc-201            Rameez Ahmad
# 14   FC-199       Rameez Ul Hassan
# 15   FC-216              Saif Ullah
# 16   FC-182         Saqlain Mahmood
# 17   Fc-207           Shoaib Azhar
# 18   FC-198           Zeeshan Munir
# 19   Fc-176           Zohaib tariq
# 20   Fc-204           Zuhaib zafar
# 21   FC-171  Muhammad Fahad Shahbaz
# 22  Fc-168           Dawood masood
# 23   Fc-169                   Faraz
# 24    FC170             Umer Rehman

# %%
df.iloc[18]
# Out:
# Column 1                           27/08/2025 14:43:31
# Column 2                   zeeshanmunir13579@gmail.com
# Column 3                                 Zeeshan Munir
# Column 4                                        FC-198
# Column 5    Python for Data Science & Machine Learning
# Column 6                   Software Project Management
# Name: 18, dtype: object

# %%
df.iloc[[18,0,15]]['Column 3']
# Out:
# 18    Zeeshan Munir
# 0     ABBAS HAIDER
# 15       Saif Ullah
# Name: Column 3, dtype: object

# %%
df2 = pd.read_csv("data/people2-100.csv")

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine        NaN    Male
# 3       4              NaN    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df2.dropna()
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 5       6  bfDD7CDEF5D865B       Erin        Day    Male
# 6       7  bE9EEf34cB72AF7  Katherine       Buck  Female
# 7       8  2EFC6A4e77FaEaC    Ricardo     Hinton    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 5          tconner@example.org   001-171-649-9856x5553    10/28/2015
# ...

# %%
df2.fillna("N/A") # Using "inplace=True" changes the original dataframe.
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine        N/A    Male
# 3       4              N/A    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df2.rename(columns={"Sex":"Gender"})
# Out:
#     Index          User Id First Name  Last Name  Gender  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine        NaN    Male
# 3       4              NaN    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df2.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        98 non-null     object
#  2   First Name     100 non-null    object
#  3   Last Name      99 non-null     object
#  4   Sex            100 non-null    object
#  5   Email          99 non-null     object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
df2['User Id']=df2['User Id'].astype('string')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        98 non-null     string
#  2   First Name     100 non-null    object
#  3   Last Name      99 non-null     object
#  4   Sex            100 non-null    object
#  5   Email          99 non-null     object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(7), string(1)
# memory usage: 7.2+ KB

# %%
df2['Age']=[0 for i in range(len(df2)) ]

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine        NaN    Male
# 3       4             <NA>    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
df2.to_csv("data/export.csv", index=False)

# %%
pd.concat([df,df2])
# Out:
#                Column 1                   Column 2       Column 3 Column 4  \
# 0   27/08/2025 16:01:53       abbash3834@gmail.com  ABBAS HAIDER    Fc 209
# 1   27/08/2025 15:23:46    abdulmoeid173@gmail.com    Abdul Moeid   FC-181
# 2   27/08/2025 18:42:47     madeelasif22@gmail.com     Adeel Asif      214
# 3   27/08/2025 15:22:09  princeahmed8966@gmail.com  Ahmed Akraam    FC-217
# 4   27/08/2025 16:54:27       jali084337@gmail.com     Ali Javed    FC-200
# ..                  ...                        ...            ...      ...
# 95                  NaN                        NaN            NaN      NaN
# 96                  NaN                        NaN            NaN      NaN
# 97                  NaN                        NaN            NaN      NaN
# 98                  NaN                        NaN            NaN      NaN
# 99                  NaN                        NaN            NaN      NaN
#
# ...

# %%
pd.merge(df,df2,on='name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14800\121791629.py in ?()
# ----> 1 pd.merge(df,df2,on='name')
#
# d:\DB\Github\learn_pandas\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# d:\DB\Github\learn_pandas\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
# ...
